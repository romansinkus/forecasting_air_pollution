# %%
# Imports

import pandas as pd
from ucimlrepo import fetch_ucirepo
import sklearn

# %%
# Fetch data and create dataframe

# fetch dataset 
air_quality = fetch_ucirepo(id=360) 
  
# data (as pandas dataframes) 
X = air_quality.data.features 
y = air_quality.data.targets 
  
# Observe metadata 
# print(air_quality.metadata) 
  
# Observe variable information 
# print(air_quality.variables)

air_quality_df = pd.concat([X, y], axis=1)

# %% [markdown]
# ### TODO: EDA
# eda.ipynb

# %% [markdown]
# ### TODO: Data Preprocessing
# data_preprocessing.ipynb

# %% [markdown]
# ### TODO: Anomaly and Event Detection
# anomaly_and_event_detection.ipynb

# %% [markdown]
# ### TODO: Feature Engineering
# feature_engineering.ipynb

# %% [markdown]
# ### TODO: Temporal Data Splitting
# temporal_data_splitting.ipynb

# %% [markdown]
# ### TODO: Regression Model Development
# regression_model.ipynb

# %% [markdown]
# ### TODO: Classification Model Development
# classification_model.ipynb

# %% [markdown]
# ### TODO: Model Assessment
# model_assessment.ipynb

# %% [markdown]
# ### TODO: Discussion
# discussion.ipynb
